# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# En este cuaderno, se resumen las herramientas y ecosistemas de ciencia de datos.

# %% [markdown]
# **Objetivos:**
# * Listar lenguajes populares para la Ciencia de Datos
# * Listar algunas bibliotecas utilizadas para la Ciencia de Datos
# * Listar algunas herramientas de libre acceso en la Ciencia de Datos

# %% [markdown]
# Algunos de los lenguajes populares que utilizan los cientiíficos de datos son:
# 1. Python
# 2. SQL
# 3. R
# 4. Julia
# 5. Scala
# 6. Java
# 7. C++
# 8. JavaScript
# 9. PHP
# 10. GO
# 11. Ruby
# 12. Visual Basic

# %% [markdown]
# Algunas de las bibliotecas comúnmente utilizadas por científicos de datos incluyen:
# 1. Pandas (Python)
# 2. Scikit-learn (Python)
# 3. NumPy (Python)
# 4. Keras (Python)
# 5. TensorFlow (Python)
# 6. PyTorch (Python)
# 7. Seaborn (Python)
# 8. MatPlotlib (Python)
# 9. GGplot2 (R)
# 10. dplyr (R)
# 11. caret (R)
# 12. Plotty (R)

# %% [markdown]
# | Herramientas para la ciencia de Datos |
# | ------------------------------------- |
# | MySQL |
# | Apache Spark |
# | Spyder |

# %% [markdown]
# ### A continuación, se presentan algunos ejemplos de evaluación de expresiones aritméticas de Python

# %%
# Esta es una expresión aritmética simple para demostrar la funcionalidad de la multiplicación y suma de números enteros
(3*4)+5
# Out:
# 17

# %%
#Esto convertirá 200 minutos a horas dividiendo entre 60
200 / 60
# Out:
# 3.3333333333333335
