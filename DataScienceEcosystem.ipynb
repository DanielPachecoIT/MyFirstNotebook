# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, the tools and ecosystems of data science are summarized.

# %% [markdown]
# **Objectives:**
# + List popular languages for Data Science
# + List some libraries used in Data Science
# + List some open-source tools in Data Science

# %% [markdown]
# Some of the popular languages used by data scientists are:
# 1. Python
# 2. SQL
# 3. R
# 4. Julia
# 5. Scala
# 6. Java
# 7. C++
# 8. JavaScript
# 9. PHP
# 10. GO
# 11. Ruby
# 12. Visual Basic

# %% [markdown]
# Some of the commonly used libraries by data scientists include:
# 1. Pandas (Python)
# 2. Scikit-learn (Python)
# 3. NumPy (Python)
# 4. Keras (Python)
# 5. TensorFlow (Python)
# 6. PyTorch (Python)
# 7. Seaborn (Python)
# 8. MatPlotlib (Python)
# 9. GGplot2 (R)
# 10. dplyr (R)
# 11. caret (R)
# 12. Plotty (R)

# %% [markdown]
# | Data Science Tools |
# | ------------------------------------- |
# | MySQL |
# | Apache Spark |
# | Spyder |

# %% [markdown]
# ### Below are some examples of evaluating arithmetic expressions in Python.

# %%
# This is a simple arithmetic expression to demonstrate the functionality of multiplying and adding integers.
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes into hours by dividing by 60.
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author:
# Daniel Pacheco Alcántara
